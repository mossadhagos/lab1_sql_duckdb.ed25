# %%
import duckdb

duckdb_path = "data/sakila.duckdb"

with duckdb.connect(duckdb_path) as conn, open("sql/load_sakila.sql") as ingest_script:
    conn.sql(ingest_script.read())
    
    films = conn.sql("FROM film;").df()

films
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[13], line 5
#       1 import duckdb
#       3 duckdb_path = "data/sakila.duckdb"
# ----> 5 with duckdb.connect(duckdb_path) as conn, open("sql/load_sakila.sql") as ingest_script:
#       6     conn.sql(ingest_script.read())
#       8     films = conn.sql("FROM film;").df()
#
# Cell In[13], line 6
#       3 duckdb_path = "data/sakila.duckdb"
#       5 with duckdb.connect(duckdb_path) as conn, open("sql/load_sakila.sql") as ingest_script:
# ----> 6     conn.sql(ingest_script.read())
#       8     films = conn.sql("FROM film;").df()
#      10 films
#
# CatalogException: Catalog Error: Failed to create view 'actor': View with name "actor" already exists!
